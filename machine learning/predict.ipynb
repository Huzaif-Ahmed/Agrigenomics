# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("merged_final24.csv")
df
# Out:
#                      Sequence          Subpopulation Cultivar ID  \
# 0    GAAAGCCGTATGTGTACCAACCTT     Temperate Japonica        C152
# 1    GGGAGCGACAGGTATGTTACCTTT               Indica I        W146
# 2    GGGAGCGGTAGTAATGTTACCTTT              Indica II        W150
# 3    GGGGGCCACCGTAGTACCACCCTC            VI/Aromatic        W129
# 4    GGGGGCGGTATGTATGTTACCTTT              Indica II        W086
# ..                        ...                    ...         ...
# 524  GGGAACGGTATTAATGTTACCTCT               Indica I        C159
# 525  GGGAGCGGTATGTATGTTACCTTT    Indica Intermediate        W167
# 526  GAGAGCCATAGGTATACCAACCTC  Japonica Intermediate        W324
# 527  GGGGACCACCGTAATGTTTCCTTC    Indica Intermediate        C198
# 528  GGGGGCCACCGGTGTGCCTCCCCC            VI/Aromatic        W255
#
#      Plant Height (cm)
# 0               100.00
# 1               127.40
# 2               104.60
# 3               151.20
# 4               103.40
# ..                 ...
# ...

# %%
chromosome_columns = ["ch" + str(i) for i in range(1, 25)]
new_df = pd.DataFrame(columns=chromosome_columns)


for index, row in df.iterrows():
    sequence = row["Sequence"]
    
    
    chromosomes = list(sequence)
    
    
    new_df.loc[index] = chromosomes


df_with_chromosomes = pd.concat([df, new_df], axis=1)

# %%
df=df_with_chromosomes
df
# Out:
#                      Sequence          Subpopulation Cultivar ID  \
# 0    GAAAGCCGTATGTGTACCAACCTT     Temperate Japonica        C152
# 1    GGGAGCGACAGGTATGTTACCTTT               Indica I        W146
# 2    GGGAGCGGTAGTAATGTTACCTTT              Indica II        W150
# 3    GGGGGCCACCGTAGTACCACCCTC            VI/Aromatic        W129
# 4    GGGGGCGGTATGTATGTTACCTTT              Indica II        W086
# ..                        ...                    ...         ...
# 524  GGGAACGGTATTAATGTTACCTCT               Indica I        C159
# 525  GGGAGCGGTATGTATGTTACCTTT    Indica Intermediate        W167
# 526  GAGAGCCATAGGTATACCAACCTC  Japonica Intermediate        W324
# 527  GGGGACCACCGTAATGTTTCCTTC    Indica Intermediate        C198
# 528  GGGGGCCACCGGTGTGCCTCCCCC            VI/Aromatic        W255
#
#      Plant Height (cm) ch1 ch2 ch3 ch4 ch5 ch6  ... ch15 ch16 ch17 ch18 ch19  \
# 0               100.00   G   A   A   A   G   C  ...    T    A    C    C    A
# ...

# %%
del df["Sequence"],df["Cultivar ID"]
df
# Out:
#              Subpopulation  Plant Height (cm) ch1 ch2 ch3 ch4 ch5 ch6 ch7 ch8  \
# 0       Temperate Japonica             100.00   G   A   A   A   G   C   C   G
# 1                 Indica I             127.40   G   G   G   A   G   C   G   A
# 2                Indica II             104.60   G   G   G   A   G   C   G   G
# 3              VI/Aromatic             151.20   G   G   G   G   G   C   C   A
# 4                Indica II             103.40   G   G   G   G   G   C   G   G
# ..                     ...                ...  ..  ..  ..  ..  ..  ..  ..  ..
# 524               Indica I              95.80   G   G   G   A   A   C   G   G
# 525    Indica Intermediate             135.20   G   G   G   A   G   C   G   G
# 526  Japonica Intermediate             156.00   G   A   G   A   G   C   C   A
# 527    Indica Intermediate             173.77   G   G   G   G   A   C   C   A
# 528            VI/Aromatic             145.80   G   G   G   G   G   C   C   A
#
# ...

# %%
label1=df["Plant Height (cm)"]
label2=df["Subpopulation"]

# %%
del df["Plant Height (cm)"],df["Subpopulation"]

# %%
df
# Out:
#     ch1 ch2 ch3 ch4 ch5 ch6 ch7 ch8 ch9 ch10  ... ch15 ch16 ch17 ch18 ch19  \
# 0     G   A   A   A   G   C   C   G   T    A  ...    T    A    C    C    A
# 1     G   G   G   A   G   C   G   A   C    A  ...    T    G    T    T    A
# 2     G   G   G   A   G   C   G   G   T    A  ...    T    G    T    T    A
# 3     G   G   G   G   G   C   C   A   C    C  ...    T    A    C    C    A
# 4     G   G   G   G   G   C   G   G   T    A  ...    T    G    T    T    A
# ..   ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...  ...
# 524   G   G   G   A   A   C   G   G   T    A  ...    T    G    T    T    A
# 525   G   G   G   A   G   C   G   G   T    A  ...    T    G    T    T    A
# 526   G   A   G   A   G   C   C   A   T    A  ...    T    A    C    C    A
# 527   G   G   G   G   A   C   C   A   C    C  ...    T    G    T    T    T
# 528   G   G   G   G   G   C   C   A   C    C  ...    T    G    C    C    T
#
#     ch20 ch21 ch22 ch23 ch24
# 0      A    C    C    T    T
# ...

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test= train_test_split(df, label1, test_size=0.8, shuffle=True)

# %% [markdown]
# # ANN for height

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(64, input_dim=24, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(x_train, y_train, epochs=100, batch_size=32)

# Make predictions
y_pred = model.predict(x_test)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14040\1092871866.py in <cell line: 10>()
#       8
#       9 # Train the model
# ---> 10 model.fit(x_train, y_train, epochs=100, batch_size=32)
#      11
#      12 # Make predictions
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ...

# %%
from sklearn.metrics import classification_report, accuracy_score, f1_score, recall_score, precision_score, confusion_matrix


print("Accuracy: ", accuracy_score(y_test, y_pred))
